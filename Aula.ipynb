# %% [markdown]
# ## Jupyter Notebook
#
# É um ambiente que viabiliza
# - Exceção de codigos
# - Criação de documento com texto formatado
# - Plotagem de Graticos
#
# > É frequentemente usado para notas de aula

# %% [markdown]
# ![4526807-ultra-wide-photography-sky-solar-eclipse-eclipse.png](attachment:4526807-ultra-wide-photography-sky-solar-eclipse-eclipse.png)

# %%
# Parte para deixar texto para comentarios
